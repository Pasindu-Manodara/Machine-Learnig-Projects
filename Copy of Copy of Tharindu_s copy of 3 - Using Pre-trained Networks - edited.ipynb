# %% [markdown]
# # Making predictions with a pre-trained network

# %%
import os
import datetime
import glob
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from matplotlib import pyplot as plt
from tensorflow.keras import layers
from PIL import Image

# %%
network = tf.keras.applications.resnet50.ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 1s 0us/step

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
data_dir = tf.keras.utils.get_file('cats_and_dogs_filterted', cache_subdir='/content/cats_and_dogs_filterted', origin=_URL, extract=True)
cats = glob.glob('/content/cats_and_dogs_filterted/cats_and_dogs_filtered/train/cats/*')
path_to_file = cats[0]
# print()
img = Image.open(path_to_file)
im = np.array(img)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 1s 0us/step

# %%
plt.imshow(im)

# %%
im.shape
# Out:
# (332, 500, 3)

# %%
i, j = 50, 50
cropped_im = im[i:i + 224, j:j + 224, :]

# %%
plt.imshow(cropped_im)

# %%
cropped_im.shape
# Out:
# (224, 224, 3)

# %%
processed_im = tf.keras.applications.resnet50.preprocess_input(tf.cast(cropped_im, tf.float32))

# %%
processed_im.shape
# Out:
# TensorShape([224, 224, 3])

# %%
processed_im[np.newaxis, ...].shape
# Out:
# TensorShape([1, 224, 224, 3])

# %%
probs = network(processed_im[np.newaxis, ...])

# %%
plt.stem(probs.numpy().flatten())
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(probs)
# Out:
# 282

# %% [markdown]
# # Using a pre-trained network as a feature extractor

# %%
network.layers
# Out:
# [<keras.src.engine.input_layer.InputLayer at 0x7dc17fd618d0>,
#  <keras.src.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7dc0f5a4c190>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0f5a4c640>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0f5a4d270>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0f5a4df00>,
#  <keras.src.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7dc0f5a4d060>,
#  <keras.src.layers.pooling.max_pooling2d.MaxPooling2D at 0x7dc0f5a4eda0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0f5a4fa90>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec2e5150>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec2e6ad0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec2e6f80>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec2e6230>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec3001f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0f5a4f820>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec301720>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0f5a4feb0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec3018a0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec3023e0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec303790>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec302470>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec303910>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec3193f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec319db0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec31a0b0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec318160>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec319a50>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec3188b0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec3187c0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec341c00>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec342aa0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec342d10>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec343d90>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec3432e0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec354310>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec342f50>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec342d70>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec341bd0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec303310>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec2e6e00>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec341ae0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec357b80>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec3574f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec36d3f0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec36cb20>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec36f2b0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0f5a4ca30>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec36e9b0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0f5a4f580>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec36ff10>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec36fd90>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec375510>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec376080>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec376ad0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec376770>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec377c70>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec375f90>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec38ca90>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec38dcf0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec38e410>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec38f400>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec38fe50>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec38fd30>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1acfa0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1ae0e0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1ae590>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1aecb0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1afdf0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1aea70>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1ae950>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec1ae350>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1ad330>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec38de40>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec3555a0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec354580>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec38d750>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec3776d0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1c0a00>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1e4d30>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1e5090>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec1c3df0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1e6e60>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1e7eb0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1e4f40>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1fe0e0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1fe590>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1fecb0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1ff7f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1e78b0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec2105e0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1e69b0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec210a30>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec2119f0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec212da0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec210fd0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec213c40>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec213a60>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec22d240>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec22d360>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec22d390>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec22c940>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec22f3d0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec22ff70>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec2404f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec22efb0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec22cf70>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1e5ff0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1e53c0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1fce50>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec1e5180>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1c3970>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec1c3b50>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec212740>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec243850>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec2581f0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec259030>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec25a950>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec25ae00>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec258dc0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec25a9b0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec264a90>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec264c40>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec25aad0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec266a10>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec2678b0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec267b20>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec266d70>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec279150>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec278100>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec27a860>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec27b790>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec279270>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec27af80>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec295510>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec2963b0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec296620>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec2976a0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec297b50>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec297ee0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec267e80>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec264250>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec2642e0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec357700>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec240dc0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1fe260>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec27b820>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec278f70>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0c2c20>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0c3be0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0c2ad0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec295e40>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0cc790>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec2414e0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0cd600>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec0c2fb0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0cef50>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0cf0a0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0cfb80>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0ce4a0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0cf400>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0cfdf0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0e44f0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0e61a0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0e74c0>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec0e4880>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0e7bb0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec0e7880>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec0e72b0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec0ceaa0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec114c10>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec116fe0>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec116890>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x7dc0ec1175b0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7dc0ec114610>,
#  <keras.src.layers.merging.add.Add at 0x7dc0ec115810>,
#  <keras.src.layers.core.activation.Activation at 0x7dc0ec115e40>,
#  <keras.src.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7dc0ec0e4dc0>,
#  <keras.src.layers.core.dense.Dense at 0x7dc0ec0e4220>]

# %%
network.layers[-2]

# %%
feature_extractor = tf.keras.Model(
    inputs=network.input,
    outputs=network.layers[-2].output
)

# %%
out = feature_extractor(processed_im[np.newaxis, ...])

# %%
out.shape
# Out:
# TensorShape([1, 2048])

# %%
(x, y), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
x
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
x_train, y_train = x[:200], y[:200]
x_test, y_test = x_test[:100], y_test[:100]

# %%
x_train.shape
# Out:
# (200, 32, 32, 3)

# %%
x_test.shape
# Out:
# (100, 32, 32, 3)

# %%
# f_train ---> (200, 2048) # (Batch, channels)
# f_test ---> (100, 2048)

# (224, 224)
# (32, 32)

# tf.image.resize
# tf.keras.applications.resnet50.preprocess_input

# %%
resized_x_train = tf.image.resize(x_train, (224, 224))

# %%
resized_x_train.shape
# Out:
# TensorShape([200, 224, 224, 3])

# %%
def get_embeddings(x):
  """Complete the implementation."""
  resized_x = tf.image.resize(x, (224, 224))
  preprocessed_x = tf.keras.applications.resnet50.preprocess_input(resized_x)
  return feature_extractor(preprocessed_x)

# %%
f_train = get_embeddings(x_train)

# %%
f_test = get_embeddings(x_test)

# %%
f_train = f_train.numpy()
y_train = y_train.flatten()

# %%
f_test = f_test.numpy()
y_test = y_test.flatten()

# %%
print(f_train.shape, y_train.shape)
print(f_test.shape, y_test.shape)
# Out:
# (200, 2048) (200,)
# (100, 2048) (100,)

# %% [markdown]
# # Visualize the embeddings

# %%
# Dimensionality reduction. -> PCA, LLE, Isomap, t-SNE
import sklearn.manifold
vals = sklearn.manifold.TSNE(2).fit_transform(f_train)

# %%
vals.shape
# Out:
# (200, 2)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=vals[:, 0], y=vals[:, 1], hue=y_train, palette='pastel')
# Out:
# <Axes: >

# %% [markdown]
# # kNN classification with k=1

# %%
print(f_test.shape)
print(f_train.shape)
# Out:
# (100, 2048)
# (200, 2048)

# %%
# Do NOT do this
a, b = len(f_test), len(f_train)
m = np.zeros((a, b))
for i in range(a):
  for j in range(b):
    m[i, j] = np.sum((f_test[i] - f_train[j]) ** 2.0 )

# %%
# m[i, j] = || f_test(i) - f_train(j) || ^ 2
#         = ||f_test(i)||^2 + ||f_train(j)||^2 - 2 <f_test(i), f_test(j)>
#         =     a    +    b     -     2*c

# %%
a = np.sum(f_test ** 2.0, axis=1)
b = np.sum(f_train ** 2.0, axis=1)
c = np.matmul(f_test, f_train.T)

# %%
m = np.reshape(a, (100, 1)) + np.reshape(b, (1, 200)) - 2 * c

# %%
import scipy.spatial

# %%
m2 = scipy.spatial.distance.cdist(f_test, f_train)  # This is the same as sqrt(m)

# %%
m.shape
# Out:
# (100, 200)

# %%
idx_of_nn = np.argmin(m, axis=1)

# %%
idx_of_nn.shape
# Out:
# (100,)

# %%
y_predict = y_train[idx_of_nn]

# %%
np.mean(y_test == y_predict)
# Out:
# 0.65
