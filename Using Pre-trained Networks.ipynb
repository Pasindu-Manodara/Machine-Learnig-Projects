# %%
import os
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from matplotlib import pyplot as plt
from tensorflow.keras import layers
from PIL import Image

# %%
network = tf.keras.applications.resnet50.ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
path_to_file = tf.keras.utils.get_file('image.jpg', 'https://vetstreet.brightspotcdn.com/dims4/default/7cc218c/2147483647/thumbnail/645x380/quality/90/?url=https%3A%2F%2Fvetstreet-brightspot.s3.amazonaws.com%2Fa5%2F69%2Fe639b7ab40c2a290e3296de726d8%2FPersian-AP-PIFN6J-645sm3614.jpg')
img = Image.open(path_to_file)
im = np.array(img)
# Out:
# Downloading data from https://vetstreet.brightspotcdn.com/dims4/default/7cc218c/2147483647/thumbnail/645x380/quality/90/?url=https%3A%2F%2Fvetstreet-brightspot.s3.amazonaws.com%2Fa5%2F69%2Fe639b7ab40c2a290e3296de726d8%2FPersian-AP-PIFN6J-645sm3614.jpg
# 49152/42151 [==================================] - 0s 0us/step

# %%
plt.imshow(im)

# %%
im.shape
# Out:
# (380, 645, 3)

# %%
i, j = 100, 300
cropped_im = im[i:i + 224, j:j + 224, :]

# %%
plt.imshow(cropped_im)

# %%
processed_im = tf.keras.applications.resnet50.preprocess_input(tf.cast(cropped_im, tf.float32))

# %%
probs = network(processed_im[np.newaxis, ...])

# %%
np.argmax(probs)
# Out:
# 283

# %%
network.layers
# Out:
# [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f3d583cc6d0>,
#  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D at 0x7f3d58375e90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d58395450>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d58362d50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50189550>,
#  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D at 0x7f3d50189c90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3d58362050>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d58c7f050>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50141dd0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d5013c0d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50152e50>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5014bc90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d5014bf90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d501b06d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50159b50>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d501b27d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5015ca90>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d50159210>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d5013cf10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50172c90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5016bed0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50168f10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500fdb10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50107510>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d500f8b10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d5010ce10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50116d90>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d5016bb10>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d5011b7d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d5012b210>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5012bd50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50121d10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d501301d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500c13d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50130910>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50134d50>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500cfa10>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d50130b90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50134490>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500dad10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500ee250>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50077450>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500f2110>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500c83d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50121c90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500dce90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50130850>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500e4390>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50107150>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d50168a10>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50116b10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d5830f350>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5007c790>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d500840d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500cfe10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50086c50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50093c50>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50093d10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50098890>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d500a7250>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d500a7bd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50098610>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d500b1610>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d5003a490>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50093bd0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5003ea50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50046710>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d5004ef10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50054690>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d50062990>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d500629d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500543d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5006f410>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0f42d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50049810>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0f88d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50073250>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c10ad10>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c10f510>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d0c11a350>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c11a810>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c0b3150>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c12dbd0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0ff550>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c10a3d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c105050>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50054150>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c105350>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50060f90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c1282d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50049990>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d500601d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50062f90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d5013c910>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d5013c890>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d500a3290>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50084f90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d50121c50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50107fd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d50098390>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0c07d0>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d5008a910>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0bf050>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c0cbc50>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0d1f90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0bfb10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c0c7cd0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0e22d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0d5f90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c0da3d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0734d0>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d0c0d5fd0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0e9750>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c085950>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c08f0d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c085590>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c087ad0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c097b50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0976d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c09ddd0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0a5310>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d0c0b1150>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c0b1a10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c0aad90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c03e050>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c044350>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c03e650>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c097850>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c08f990>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c08c5d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c0de6d0>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d5010ea50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d50162090>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d500b10d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c04c750>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c051050>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c051a90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c053bd0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3d0c05e5d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c05ef90>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c062810>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3cfc7be210>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7be790>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc7d5450>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7d0b50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7de0d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc7e1510>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7d9d90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7ec6d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3d0c062990>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc7f23d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7c95d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7fadd0>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3cfc7fa910>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7ec350>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc78c3d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc78cb90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc792390>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc795310>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc79fd10>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7ec690>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc792590>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7af4d0>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3cfc792a50>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7a5e10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc73e950>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc744c90>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7b9190>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc7aa750>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3cfc7f2450>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7a5610>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3cfc79b7d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f3d0c057990>,
#  <tensorflow.python.keras.layers.merge.Add at 0x7f3d5003e110>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f3cfc7c44d0>,
#  <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D at 0x7f3d501b0810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3d0c087d50>]

# %%
feature_extractor = tf.keras.Model(inputs=network.input, outputs=network.layers[-2].output)

# %%
out = feature_extractor(processed_im[np.newaxis, ...])

# %%
out.shape
# Out:
# TensorShape([1, 2048])

# %%
(x, y), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step

# %%
x_train, y_train = x[:200], y[:200]
x_test, y_test = x_test[:100], y_test[:100]

# %%
def get_embeddings(x):
  all_embs = []
  for im in x:
    im = tf.image.resize(im, size=(224, 224))
    im = tf.keras.applications.resnet50.preprocess_input(tf.cast(im, tf.float32))
    embedding = feature_extractor(im[np.newaxis, ...])
    all_embs.append(embedding.numpy()[0])

  return np.array(all_embs)

# %%
train_embeddings = get_embeddings(x_train)

# %%
test_embeddings = get_embeddings(x_test)

# %%
train_embeddings.shape
# Out:
# (200, 2048)

# %%
test_embeddings.shape
# Out:
# (100, 2048)
